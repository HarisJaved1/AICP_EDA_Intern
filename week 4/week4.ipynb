# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the CSV file

dataset = pd.read_csv("menu.csv")
dataset.head(2)
# Out:
#     Category               Item    Serving Size  Calories  Calories from Fat  \
# 0  Breakfast       Egg McMuffin  4.8 oz (136 g)       300                120
# 1  Breakfast  Egg White Delight  4.8 oz (135 g)       250                 70
#
#    Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0       13.0                         20            5.0
# 1        8.0                         12            3.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 0                             25        0.0  ...             31
# 1                             15        0.0  ...             30
#
#    Carbohydrates (% Daily Value)  Dietary Fiber  \
# 0                             10              4
# 1                             10              4
#
#    Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 0                             17       3       17                         10
# ...

# %%
#Taking relevant data

rel_data = dataset[['Calories', 'Total Fat', 'Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)', 'Calcium (% Daily Value)', 'Iron (% Daily Value)']]
rel_data.head(2)
# Out:
#    Calories  Total Fat  Carbohydrates  Dietary Fiber  Sugars  Protein  \
# 0       300       13.0             31              4       3       17
# 1       250        8.0             30              4       3       18
#
#    Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 0                         10                          0
# 1                          6                          0
#
#    Calcium (% Daily Value)  Iron (% Daily Value)
# 0                       25                    15
# 1                       25                     8

# %%
#Checking the stats of this data 
rel_data.describe()
# Out:
#           Calories   Total Fat  Carbohydrates  Dietary Fiber      Sugars  \
# count   260.000000  260.000000     260.000000     260.000000  260.000000
# mean    368.269231   14.165385      47.346154       1.630769   29.423077
# std     240.269886   14.205998      28.252232       1.567717   28.679797
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%     210.000000    2.375000      30.000000       0.000000    5.750000
# 50%     340.000000   11.000000      44.000000       1.000000   17.500000
# 75%     500.000000   22.250000      60.000000       3.000000   48.000000
# max    1880.000000  118.000000     141.000000       7.000000  128.000000
#
#           Protein  Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# count  260.000000                 260.000000                 260.000000
# mean    13.338462                  13.426923                   8.534615
# std     11.426146                  24.366381                  26.345542
# ...

# %%
#Now checking the maximum values of these columns 
rel_data.max()
# Out:
# Calories                     1880.0
# Total Fat                     118.0
# Carbohydrates                 141.0
# Dietary Fiber                   7.0
# Sugars                        128.0
# Protein                        87.0
# Vitamin A (% Daily Value)     170.0
# Vitamin C (% Daily Value)     240.0
# Calcium (% Daily Value)        70.0
# Iron (% Daily Value)           40.0
# dtype: float64

# %%
# Creating the correlation matrix 

cor_matrix = rel_data.corr()

# Using seaborn
plt.figure(figsize=(7, 7))
sns.heatmap(cor_matrix, cmap='cividis', annot=True, fmt=".2f")
plt.title('Correlation between Calories and other columns')  
plt.show()
